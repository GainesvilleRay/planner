# %%
#python3.7
#utf8

"""This script takes a csv file with information related to summer camps
and outputs a text file that is formatted for publication. It was created
Feb. 20, 2019 by Douglas Ray for The Gainesville Sun."""

# libraries
import csv

filename = 'submissions.csv'

# %%
# Submissions in the category for Art
def cat_art():
    with open(filename) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        headers = next(csv_reader)
        f=open('planner.txt', 'a')
        f.write('ART' + '\n\n')
        
        for row in csv_reader:
            campname = row[2].strip()
            category = row[3].strip()
            description = row[4].strip()
            dates = row[5].strip().replace(' - ', '-')
            times = row[6].strip().replace('P.M.', ' p.m.').replace('A.M.', ' a.m.').replace('  ', ' ')
            location = row[7].strip().replace(', FL', '')
            cost = row[8].strip().replace('.00', '')
            website = row[9].strip().replace('Http://', 'http://')
            phone = row[10].strip()
            email = row[11].strip()
            deadline = row[12].strip()
            
            if "Art" in category:
                f.write(campname + ': ' + description + '\n')
                f.write('Dates: ' + dates + '\n')
                f.write('Times: '+ times + '\n')
                f.write('Location: ' + location + '\n')
                f.write('Cost: ' + cost + '\n')
                f.write('Contact: ' + phone + '; ' + email + '\n')
                f.write('Website: ' + website + '\n')
                f.write('Deadline: ' + deadline + '\n\n')
        f.close()

# %%
# Submissions in the category for Education/Enrichment
def cat_education():
    with open(filename) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        headers = next(csv_reader)
        f=open('planner.txt', 'a')
        f.write('EDUCATION/ENRICHMENT\n\n')
        
        for row in csv_reader:
            campname = row[2].strip()
            category = row[3].strip()
            description = row[4].strip()
            dates = row[5].strip().replace(' - ', '-')
            times = row[6].strip().replace('P.M.', ' p.m.').replace('A.M.', ' a.m.').replace('  ', ' ')
            location = row[7].strip().replace(', FL', '')
            cost = row[8].strip().replace('.00', '')
            website = row[9].strip().replace('Http://', 'http://')
            phone = row[10].strip()
            email = row[11].strip()
            deadline = row[12].strip()
            
            if "Education" in category:
                f.write(campname + ': ' + description + '\n')
                f.write('Dates: ' + dates + '\n')
                f.write('Times: '+ times + '\n')
                f.write('Location: ' + location + '\n')
                f.write('Cost: ' + cost + '\n')
                f.write('Contact: ' + phone + '; ' + email + '\n')
                f.write('Website: ' + website + '\n')
                f.write('Deadline: ' + '\n\n')
        f.close()

# %%
# Submissions in the category for General
def cat_general():
    with open(filename) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        headers = next(csv_reader)
        f=open('planner.txt', 'a')
        f.write('<p><strong>GENERAL</strong></p><p></p>')
        
        for row in csv_reader:
            campname = row[2].strip()
            category = row[3].strip()
            description = row[4].strip()
            dates = row[5].strip().replace(' - ', '-')
            times = row[6].strip().replace('P.M.', ' p.m.').replace('A.M.', ' a.m.').replace('  ', ' ')
            location = row[7].strip().replace(', FL', '')
            cost = row[8].strip().replace('.00', '')
            website = row[9].strip().replace('Http://', 'http://')
            phone = row[10].strip()
            email = row[11].strip()
            deadline = row[12].strip()
            
            if "General" in category:
                f.write('<p><strong>' + campname + '</strong>: ' + description + '</p>')
                f.write('<p><strong>Dates</strong>: ' + dates + '</p>')
                f.write('<p><strong>Times</strong>: ' + times + '</p>')
                f.write('<p><strong>Location</strong>: ' + location + '</p>')
                f.write('<p><strong>Cost</strong>: ' + cost + '</p>')
                f.write('<p><strong>Contact</strong>: ' + phone + ', ' + email + '</p>')
                f.write('<p><strong>Website</strong>: ' + website + '</p>')
                f.write('<p><strong>Deadline</strong>: ' + '</p><p></p>')
        f.close()

# %%
# Submissions in the category for Music
def cat_music():
    with open(filename) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        headers = next(csv_reader)
        f=open('planner.txt', 'a')
        f.write('MUSIC\n\n')
        
        for row in csv_reader:
            campname = row[2].strip()
            category = row[3].strip()
            description = row[4].strip()
            dates = row[5].strip().replace(' - ', '-')
            times = row[6].strip().replace('P.M.', ' p.m.').replace('A.M.', ' a.m.').replace('  ', ' ')
            location = row[7].strip().replace(', FL', '')
            cost = row[8].strip().replace('.00', '')
            website = row[9].strip().replace('Http://', 'http://')
            phone = row[10].strip()
            email = row[11].strip()
            deadline = row[12].strip()
            
            if "Music" in category:
                f.write(campname + ': ' + description + '\n')
                f.write('Dates: ' + dates + '\n')
                f.write('Times: '+ times + '\n')
                f.write('Location: ' + location + '\n')
                f.write('Cost: ' + cost + '\n')
                f.write('Contact: ' + phone + '; ' + email + '\n')
                f.write('Website: ' + website + '\n')
                f.write('Deadline: ' + '\n\n')
        f.close()

# %%
# Submissions in the category for Overnight
def cat_overnight():
    with open(filename) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        headers = next(csv_reader)
        f=open('planner.txt', 'a')
        f.write('OVERNIGHT\n\n')
        
        for row in csv_reader:
            campname = row[2].strip()
            category = row[3].strip()
            description = row[4].strip()
            dates = row[5].strip().replace(' - ', '-')
            times = row[6].strip().replace('P.M.', ' p.m.').replace('A.M.', ' a.m.').replace('  ', ' ')
            location = row[7].strip().replace(', FL', '')
            cost = row[8].strip().replace('.00', '')
            website = row[9].strip().replace('Http://', 'http://')
            phone = row[10].strip()
            email = row[11].strip()
            deadline = row[12].strip()
            
            if "Overnight" in category:
                f.write(campname + ': ' + description + '\n')
                f.write('Dates: ' + dates + '\n')
                f.write('Times: '+ times + '\n')
                f.write('Location: ' + location + '\n')
                f.write('Cost: ' + cost + '\n')
                f.write('Contact: ' + phone + '; ' + email + '\n')
                f.write('Website: ' + website + '\n')
                f.write('Deadline: ' + '\n\n')
        f.close()

# %%
# Submissions in the category for Sports
def cat_sports():
    with open(filename) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        headers = next(csv_reader)
        f=open('planner.txt', 'a')
        f.write('SPORTS\n\n')
        
        for row in csv_reader:
            campname = row[2].strip()
            category = row[3].strip()
            description = row[4].strip()
            dates = row[5].strip().replace(' - ', '-')
            times = row[6].strip().replace('P.M.', ' p.m.').replace('A.M.', ' a.m.').replace('  ', ' ')
            location = row[7].strip().replace(', FL', '')
            cost = row[8].strip().replace('.00', '')
            website = row[9].strip().replace('Http://', 'http://')
            phone = row[10].strip()
            email = row[11].strip()
            deadline = row[12].strip()
            
            if "Sports" in category:
                f.write(campname + ': ' + description + '\n')
                f.write('Dates: ' + dates + '\n')
                f.write('Times: '+ times + '\n')
                f.write('Location: ' + location + '\n')
                f.write('Cost: ' + cost + '\n')
                f.write('Contact: ' + phone + '; ' + email + '\n')
                f.write('Website: ' + website + '\n')
                f.write('Deadline: ' + '\n\n')
        f.close()

# %%
# Submissions in the category for Theater
def cat_theater():
    with open(filename) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        headers = next(csv_reader)
        f=open('planner.txt', 'a')
        f.write('THEATER\n\n')
        
        for row in csv_reader:
            campname = row[2].strip()
            category = row[3].strip()
            description = row[4].strip()
            dates = row[5].strip().replace(' - ', '-')
            times = row[6].strip().replace('P.M.', ' p.m.').replace('A.M.', ' a.m.').replace('  ', ' ')
            location = row[7].strip().replace(', FL', '')
            cost = row[8].strip().replace('.00', '')
            website = row[9].strip().replace('Http://', 'http://')
            phone = row[10].strip()
            email = row[11].strip()
            deadline = row[12].strip()
            
            if "Theater" in category:
                f.write(campname + ': ' + description + '\n')
                f.write('Dates: ' + dates + '\n')
                f.write('Times: '+ times + '\n')
                f.write('Location: ' + location + '\n')
                f.write('Cost: ' + cost + '\n')
                f.write('Contact: ' + phone + '; ' + email + '\n')
                f.write('Website: ' + website + '\n')
                f.write('Deadline: ' + '\n\n')
        f.close()

# %%
def main():
    f=open('planner.txt', 'w')
    cat_art()
    cat_education()
    cat_general()
    cat_music()
    cat_overnight()
    cat_sports()
    cat_theater()
    f.close()
    
if __name__ == '__main__':
    main()
    
f=open("planner.txt", "r")
contents = f.read()
print(contents)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-ff28b426495a> in <module>
#      11
#      12 if __name__ == '__main__':
# ---> 13     main()
#      14
#      15 f=open("planner.txt", "r")
#
# <ipython-input-9-ff28b426495a> in main()
#       1 def main():
#       2     f=open('planner.txt', 'w')
# ----> 3     cat_art()
#       4     cat_education()
#       5     cat_general()
#
# <ipython-input-2-d65177950afc> in cat_art()
#       3     with open(filename) as csv_file:
#       4         csv_reader = csv.reader(csv_file, delimiter=',')
# ----> 5         headers = next(csv_reader)
#       6         f=open('planner.txt', 'a')
#       7         f.write('ART' + '\n\n')
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# ...
